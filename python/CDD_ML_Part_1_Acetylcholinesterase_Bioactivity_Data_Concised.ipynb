# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
#
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.3.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.9.2)
# Collecting url-normalize>=2.0 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.4 MB/s eta 0:00:00
# Downloading requests_cache-1.3.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 2.7 MB/s eta 0:00:00
# Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.1 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-26.1.0 chembl_webresource_client-0.10.9 requests-cache-1.3.0 url-normalize-2.2.1

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []          Anopheles gambiae
# 8                []             Bemisia tabaci
# 9                []  Leptinotarsa decemlineata
# 10               []     Nephotettix cincticeps
# 11               []              Gallus gallus
# 12               []                Danio rerio
# 13               []              Aedes aegypti
# 14               []               Homo sapiens
# 15               []            Musca domestica
# 16               []        Plutella xylostella
# 17               []            Musca domestica
# 18               []  Pediculus humanus capitis
# 19               []          Spodoptera litura
# 20               []      Laodelphax striatella
# 21               []        Schizaphis graminum
# 22               []               Homo sapiens
# 23               []          Rattus norvegicus
# 24               []     Caenorhabditis elegans
# 25               []             Equus caballus
# 26               []             Equus caballus
# 27               []     Canis lupus familiaris
# 28               []               Mus musculus
# 29               []          Rattus norvegicus
# 30               []               Homo sapiens
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   18.0
# 1                                Acetylcholinesterase   16.0
# 2                                Acetylcholinesterase   16.0
# 3                                Acetylcholinesterase   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   16.0
# 6                                Acetylcholinesterase   16.0
# 7                                Acetylcholinesterase   16.0
# 8                                               AChE2   16.0
# 9                                Acetylcholinesterase   16.0
# 10               Ace-orthologous acetylcholinesterase   16.0
# 11                               Acetylcholinesterase   16.0
# 12                               Acetylcholinesterase   16.0
# 13                               Acetylcholinesterase   16.0
# 14                                       Protein CutA   16.0
# 15                               Acetylcholinesterase   15.0
# 16                               Acetylcholinesterase   15.0
# 17                               Acetylcholinesterase   15.0
# 18                               Acetylcholinesterase   15.0
# 19                               Acetylcholinesterase   15.0
# 20                               Acetylcholinesterase   15.0
# 21                               Acetylcholinesterase   15.0
# 22                       Cholinesterases; ACHE & BCHE   14.0
# 23  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 24                             Acetylcholinesterase 1   14.0
# 25                              Butyrylcholinesterase   11.0
# 26                                     Cholinesterase   11.0
# 27                                     Cholinesterase   11.0
# 28                                     Cholinesterase   10.0
# 29                              Butyrylcholinesterase   10.0
# 30                                     Cholinesterase    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL2242744
# 1                False        CHEMBL220
# 2                False       CHEMBL4780
# 3                False       CHEMBL3198
# 4                False       CHEMBL3199
# 5                False       CHEMBL4078
# 6                False       CHEMBL4768
# 7                False    CHEMBL2046266
# 8                False    CHEMBL2366409
# 9                False    CHEMBL2366490
# 10               False    CHEMBL2366514
# 11               False    CHEMBL3227914
# 12               False    CHEMBL3308995
# 13               False    CHEMBL4295607
# 14               False    CHEMBL6067022
# 15               False       CHEMBL5752
# 16               False    CHEMBL2242729
# 17               False    CHEMBL2242743
# 18               False    CHEMBL2362988
# 19               False    CHEMBL2366422
# 20               False    CHEMBL2366446
# 21               False    CHEMBL2366511
# 22               False    CHEMBL2095233
# 23               False    CHEMBL2111475
# 24               False    CHEMBL3341583
# 25               False       CHEMBL5077
# 26               False       CHEMBL5763
# 27               False    CHEMBL4630814
# 28               False       CHEMBL2528
# 29               False       CHEMBL3403
# 30               False       CHEMBL1914
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'O60888', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 23  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 24  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'Q9N1N9', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'P81908', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'P32750', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'Q03311', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'Q9JKC1', 'component_descriptio...     SINGLE PROTEIN
# 30  [{'accession': 'P06276', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     7227
# 1     9606
# 2     7787
# 3    10090
# 4    10116
# 5     8005
# 6     9913
# 7     7165
# 8     7038
# 9     7539
# 10   94400
# 11    9031
# 12    7955
# 13    7159
# 14    9606
# 15    7370
# 16   51655
# 17    7370
# 18  121226
# 19   69820
# 20  195883
# 21   13262
# 22    9606
# 23   10116
# 24    6239
# 25    9796
# 26    9796
# 27    9615
# 28   10090
# 29   10116
# 30    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")[:1000]
df = pd.DataFrame.from_dict(res)
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        33969                  []
# 1        None             None        37563                  []
# 2        None             None        37565                  []
# 3        None             None        38902                  []
# 4        None             None        41170                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4    CHEMBL643384  Inhibitory concentration against acetylcholine...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism      target_pref_name target_tax_id text_value  toid  type  \
# 0    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 1    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 2    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 3    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 4    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065        None  0.75
# 1    uM  UO_0000065        None   0.1
# 2    uM  UO_0000065        None  50.0
# 3    uM  UO_0000065        None   0.3
# 4    uM  UO_0000065        None   0.8
#
# [5 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipython-input-3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None        33969                  []
# 1          None             None        37563                  []
# 2          None             None        37565                  []
# 3          None             None        38902                  []
# 4          None             None        41170                  []
# ..          ...              ...          ...                 ...
# 995        None             None      1207241                  []
# 996        None             None      1207864                  []
# 997        None             None      1207871                  []
# 998        None             None      1208138                  []
# 999        None             None      1209126                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4      CHEMBL643384  Inhibitory concentration against acetylcholine...
# ..              ...                                                ...
# 995    CHEMBL644833  In vitro inhibition of human acetylcholinester...
# 996    CHEMBL644119     In vitro inhibition of human recombinant AChE.
# 997    CHEMBL644119     In vitro inhibition of human recombinant AChE.
# 998    CHEMBL885303  Concentration required to inhibit 50% of Acety...
# 999    CHEMBL644119     In vitro inhibition of human recombinant AChE.
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 995          B                    None                   None  BAO_0000190
# 996          B                    None                   None  BAO_0000190
# 997          B                    None                   None  BAO_0000190
# 998          B                    None                   None  BAO_0000190
# 999          B                    None                   None  BAO_0000190
#
#      ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 1    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 2    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 3    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 4    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# ..   ...             ...                   ...           ...        ...   ...
# 995  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 996  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 997  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 998  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 999  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#      type units    uo_units upper_value value
# 0    IC50    uM  UO_0000065        None  0.75
# 1    IC50    uM  UO_0000065        None   0.1
# 2    IC50    uM  UO_0000065        None  50.0
# 3    IC50    uM  UO_0000065        None   0.3
# 4    IC50    uM  UO_0000065        None   0.8
# ..    ...   ...         ...         ...   ...
# 995  IC50    uM  UO_0000065        None  0.16
# 996  IC50    uM  UO_0000065        None   0.5
# 997  IC50    uM  UO_0000065        None   0.5
# 998  IC50    nM  UO_0000065        None   6.8
# 999  IC50    uM  UO_0000065        None   0.5
#
# [979 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 743

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None        33969                  []
# 1          None             None        37563                  []
# 2          None             None        37565                  []
# 3          None             None        38902                  []
# 4          None             None        41170                  []
# ..          ...              ...          ...                 ...
# 993        None             None      1205978                  []
# 995        None             None      1207241                  []
# 997        None             None      1207871                  []
# 998        None             None      1208138                  []
# 999        None             None      1209126                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3      CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4      CHEMBL643384  Inhibitory concentration against acetylcholine...
# ..              ...                                                ...
# 993    CHEMBL644833  In vitro inhibition of human acetylcholinester...
# 995    CHEMBL644833  In vitro inhibition of human acetylcholinester...
# 997    CHEMBL644119     In vitro inhibition of human recombinant AChE.
# 998    CHEMBL885303  Concentration required to inhibit 50% of Acety...
# 999    CHEMBL644119     In vitro inhibition of human recombinant AChE.
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 993          B                    None                   None  BAO_0000190
# 995          B                    None                   None  BAO_0000190
# 997          B                    None                   None  BAO_0000190
# 998          B                    None                   None  BAO_0000190
# 999          B                    None                   None  BAO_0000190
#
#      ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 1    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 2    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 3    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 4    ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# ..   ...             ...                   ...           ...        ...   ...
# 993  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 995  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 997  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 998  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 999  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#      type units    uo_units upper_value value
# 0    IC50    uM  UO_0000065        None  0.75
# 1    IC50    uM  UO_0000065        None   0.1
# 2    IC50    uM  UO_0000065        None  50.0
# 3    IC50    uM  UO_0000065        None   0.3
# 4    IC50    uM  UO_0000065        None   0.8
# ..    ...   ...         ...         ...   ...
# 993  IC50    uM  UO_0000065        None  0.65
# 995  IC50    uM  UO_0000065        None  0.16
# 997  IC50    uM  UO_0000065        None   0.5
# 998  IC50    nM  UO_0000065        None   6.8
# 999  IC50    uM  UO_0000065        None   0.5
#
# [743 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1         CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2         CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3         CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4         CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ..                 ...                                                ...
# 993       CHEMBL104334  CN(C)Cc1ccc(CSCCNc2cc(Nc3ncccc3[N+](=O)[O-])c(...
# 995       CHEMBL320291  CNc1cc(NCCSCc2ccc(CN(C)C)o2)c([N+](=O)[O-])cc1...
# 997       CHEMBL315385  C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)NCCCC3)CC1
# 998       CHEMBL542543      Cc1nc2ccc(C(=O)CCC3CCN(Cc4ccccc4)CC3)cc2s1.Cl
# 999        CHEMBL85404  COc1ccc2c3c1OC1C[C@@H](O)C=C[C@@]31CC[N+](C)(C)C2
#
#     standard_value
# 0            750.0
# 1            100.0
# 2          50000.0
# 3            300.0
# 4            800.0
# ..             ...
# 993          650.0
# 995          160.0
# 997          500.0
# 998            6.8
# 999          500.0
#
# [743 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1         CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2         CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3         CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4         CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ..                 ...                                                ...
# 738       CHEMBL104334  CN(C)Cc1ccc(CSCCNc2cc(Nc3ncccc3[N+](=O)[O-])c(...
# 739       CHEMBL320291  CNc1cc(NCCSCc2ccc(CN(C)C)o2)c([N+](=O)[O-])cc1...
# 740       CHEMBL315385  C[N+]1(Cc2ccccc2)CCC(CCC(=O)c2ccc3c(c2)NCCCC3)CC1
# 741       CHEMBL542543      Cc1nc2ccc(C(=O)CCC3CCN(Cc4ccccc4)CC3)cc2s1.Cl
# 742        CHEMBL85404  COc1ccc2c3c1OC1C[C@@H](O)C=C[C@@]31CC[N+](C)(C)C2
#
#      standard_value     class
# 0             750.0    active
# 1             100.0    active
# 2           50000.0  inactive
# 3             300.0    active
# 4             800.0    active
# ..              ...       ...
# 738           650.0    active
# 739           160.0    active
# 740           500.0    active
# 741             6.8    active
# 742           500.0    active
#
# [743 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 89%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 78%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 80%)

# %%
! ls -l
# Out:
# total 628
# -rw-r--r-- 1 root root 462741 Feb 24 02:33 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  46675 Feb 24 02:33 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  53174 Feb 24 02:34 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  70815 Feb 24 02:34 acetylcholinesterase.zip
# drwxr-xr-x 1 root root   4096 Jan 16 14:24 sample_data

# %% [markdown]
# ---
